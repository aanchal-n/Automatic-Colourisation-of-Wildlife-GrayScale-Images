# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
defaultPath='/content/drive/MyDrive/Animals_Dataset'

# %%
import numpy as np
import pandas as pd
import cv2
import os
from glob import glob

# %%
images_path = '/content/drive/MyDrive/Animals-151/acinonyx-jubatus/'
images = glob(images_path+'*.jpg')


len(images)
# Out:
# 33

# %%
from keras.layers import Conv2D, UpSampling2D
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from skimage.color import rgb2lab, lab2rgb
from skimage.transform import resize
from skimage.io import imsave
import numpy as np
import tensorflow as tf

path = '/content/drive/MyDrive/Animals-151/'

#Normalize images - divide by 255
train_datagen = ImageDataGenerator(rescale=1. / 255)

#Resize images, if needed
train = train_datagen.flow_from_directory(path, 
                                          target_size=(256, 256), 
                                          batch_size=340, 
                                          class_mode=None)

X =[]
Y =[]
for img in train[0]:
  try:
      lab = rgb2lab(img)
      X.append(lab[:,:,0]) 
      Y.append(lab[:,:,1:] / 128) #normalise to -1 and 1
  except:
     print('error')
X = np.array(X)
Y = np.array(Y)
X = X.reshape(X.shape+(1,)) #dimensions to be the same for X and Y
print(X.shape)
print(Y.shape)


#Encoder

model = Sequential()
model.add(Conv2D(64, (3, 3), activation='relu', padding='same', strides=2, input_shape=(256, 256, 1)))
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(128, (3,3), activation='relu', padding='same', strides=2))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same', strides=2))
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(Conv2D(512, (3,3), activation='relu', padding='same',strides=2))
model.add(Conv2D(1024, (3,3), activation='relu', padding='same'))
model.add(Conv2D(1024, (3,3), activation='relu', padding='same'))
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
#Decoder

model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3,3), activation='relu', padding='same'))
model.add(Conv2D(16, (3,3), activation='relu', padding='same'))
model.add(Conv2D(2, (3, 3), activation='tanh', padding='same'))
model.add(UpSampling2D((2, 2)))
model.compile(optimizer='adam', loss='mse' , metrics=['accuracy'])
model.summary()


model.fit(X,Y,validation_split=0.1, epochs=300, batch_size=16)

model.save('other_files/colorize_autoencoder.model')
# Out:
# Found 2415 images belonging to 61 classes.
# (340, 256, 256, 1)
# (340, 256, 256, 2)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_40 (Conv2D)          (None, 128, 128, 64)      640
#
#  conv2d_41 (Conv2D)          (None, 128, 128, 128)     73856
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 128)       147584
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 256)       295168
#
#  conv2d_44 (Conv2D)          (None, 32, 32, 256)       590080
#
#  conv2d_45 (Conv2D)          (None, 32, 32, 512)       1180160
#
#  conv2d_46 (Conv2D)          (None, 16, 16, 512)       2359808
#
#  conv2d_47 (Conv2D)          (None, 16, 16, 1024)      4719616
#
#  conv2d_48 (Conv2D)          (None, 16, 16, 1024)      9438208
#
#  conv2d_49 (Conv2D)          (None, 16, 16, 512)       4719104
#
#  conv2d_50 (Conv2D)          (None, 16, 16, 256)       1179904
#
# ...

# %%
tf.keras.models.load_model(
    'other_files/colorize_autoencoder.model',
    custom_objects=None,
    compile=True)
img1_color=[]
img1=img_to_array(load_img('/content/drive/MyDrive/acinonyx-jubatus-greyscale/11.jpg'))
img1 = resize(img1 ,(256,256))
img1_color.append(img1)
img1_color = np.array(img1_color, dtype=float)
img1_color = rgb2lab(1.0/255*img1_color)[:,:,:,0]
img1_color = img1_color.reshape(img1_color.shape+(1,))
output1 = model.predict(img1_color)
output1 = output1*128
result = np.zeros((256, 256, 3))
result[:,:,0] = img1_color[0][:,:,0]
result[:,:,1:] = output1[0]
imsave("result.jpg", lab2rgb(result))
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
image_pairs = [
             
              ('result.jpg','/content/drive/MyDrive/acinonyx-jubatus-greyscale/11.jpg','/content/drive/MyDrive/Animals-151/acinonyx-jubatus/11.jpg'),
               
               ]
for c, g,o in image_pairs:
  color = mpimg.imread(c)
  gray  = mpimg.imread(g)
  true = mpimg.imread(o)
  f, axarr = plt.subplots(1, 3)
  f.set_size_inches(15, 15)
  axarr[0].imshow(gray, cmap='gray')
  axarr[1].imshow(color)
  axarr[2].imshow(true)
  axarr[0].axis('off'), axarr[1].axis('off'),axarr[2].axis('off')
  plt.show()

# %% [markdown]
# The above image on the extreme left is the greyscale and the one in the middle is the predicted image from the model and the rightmost image is the original color image

# %%
original = cv2.imread('/content/drive/MyDrive/Animals-151/acinonyx-jubatus/11.jpg')
historg = cv2.calcHist([original],[0,1,2],None,[8,8,8],[0,256,0,256,0,256])
historg = cv2.normalize(historg,historg).flatten()

# %%
pred = cv2.imread('result.jpg')
histpred = cv2.calcHist([pred],[0,1,2],None,[8,8,8],[0,256,0,256,0,256])
histpred = cv2.normalize(histpred,histpred).flatten()

# %%
d_intersection=cv2.compareHist(histpred,historg,cv2.HISTCMP_INTERSECT)

# %%
d_chisqr = cv2.compareHist(histpred,historg,cv2.HISTCMP_CHISQR)

# %%
d_chisqr
# Out:
# 1.9767629220809144

# %%
d_intersection
# Out:
# 0.5507017060881481

# %% [markdown]
# As you can see this the CHISQR Metric for acinonyx-jubatus/11.jpg image comes out to be 1.9767 and INTERSECTION comes out to be 0.5507

# %%
tf.keras.models.load_model(
    'other_files/colorize_autoencoder.model',
    custom_objects=None,
    compile=True)
img1_color=[]
img1=img_to_array(load_img('ailuropoda-1-greyscale.jpg'))
img1 = resize(img1 ,(256,256))
img1_color.append(img1)
img1_color = np.array(img1_color, dtype=float)
img1_color = rgb2lab(1.0/255*img1_color)[:,:,:,0]
img1_color = img1_color.reshape(img1_color.shape+(1,))
output1 = model.predict(img1_color)
output1 = output1*128
result = np.zeros((256, 256, 3))
result[:,:,0] = img1_color[0][:,:,0]
result[:,:,1:] = output1[0]
imsave("result1.jpg", lab2rgb(result))
#/content/drive/MyDrive/Animals-151/ailuropoda-melanoleuca/1.jpg
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
image_pairs = [
             
              ('result1.jpg','ailuropoda-1-greyscale.jpg','/content/drive/MyDrive/Animals-151/ailuropoda-melanoleuca/1.jpg'),
               
               ]
for c, g,o in image_pairs:
  color = mpimg.imread(c)
  gray  = mpimg.imread(g)
  true = mpimg.imread(o)
  f, axarr = plt.subplots(1, 3)
  f.set_size_inches(15, 15)
  axarr[0].imshow(gray, cmap='gray')
  axarr[1].imshow(color)
  axarr[2].imshow(true)
  axarr[0].axis('off'), axarr[1].axis('off'),axarr[2].axis('off')
  plt.show()

# %%
original = cv2.imread('/content/drive/MyDrive/Animals-151/ailuropoda-melanoleuca/1.jpg')
historg = cv2.calcHist([original],[0,1,2],None,[8,8,8],[0,256,0,256,0,256])
historg = cv2.normalize(historg,historg).flatten()

# %%
pred = cv2.imread('result1.jpg')
histpred = cv2.calcHist([pred],[0,1,2],None,[8,8,8],[0,256,0,256,0,256])
histpred = cv2.normalize(histpred,histpred).flatten()

# %%
d_intersection=cv2.compareHist(histpred,historg,cv2.HISTCMP_INTERSECT)

# %%
d_chisqr = cv2.compareHist(histpred,historg,cv2.HISTCMP_CHISQR)

# %%
d_chisqr
# Out:
# 2.042309928945734

# %%
d_intersection
# Out:
# 1.8086735759861767

# %% [markdown]
# As you can see this the CHISQR Metric for ailuropoda-melanoleuca/1.jpg image comes out to be 2.0423 and INTERSECTION comes out to be 1.8086

# %%
tf.keras.models.load_model(
    'other_files/colorize_autoencoder.model',
    custom_objects=None,
    compile=True)
img1_color=[]
img1=img_to_array(load_img('cerathotherium-30-greyscale.jpg'))
img1 = resize(img1 ,(256,256))
img1_color.append(img1)
img1_color = np.array(img1_color, dtype=float)
img1_color = rgb2lab(1.0/255*img1_color)[:,:,:,0]
img1_color = img1_color.reshape(img1_color.shape+(1,))
output1 = model.predict(img1_color)
output1 = output1*128
result = np.zeros((256, 256, 3))
result[:,:,0] = img1_color[0][:,:,0]
result[:,:,1:] = output1[0]
imsave("result2.jpg", lab2rgb(result))
#/content/drive/MyDrive/Animals-151/ceratotherium-simum/30.jpg
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
image_pairs = [
             
              ('result2.jpg','cerathotherium-30-greyscale.jpg','/content/drive/MyDrive/Animals-151/ceratotherium-simum/30.jpg'),
               
               ]
for c, g,o in image_pairs:
  color = mpimg.imread(c)
  gray  = mpimg.imread(g)
  true = mpimg.imread(o)
  f, axarr = plt.subplots(1, 3)
  f.set_size_inches(15, 15)
  axarr[0].imshow(gray, cmap='gray')
  axarr[1].imshow(color)
  axarr[2].imshow(true)
  axarr[0].axis('off'), axarr[1].axis('off'),axarr[2].axis('off')
  plt.show()

# %%
original = cv2.imread('/content/drive/MyDrive/Animals-151/ceratotherium-simum/30.jpg')
historg = cv2.calcHist([original],[0,1,2],None,[8,8,8],[0,256,0,256,0,256])
historg = cv2.normalize(historg,historg).flatten()

# %%
pred = cv2.imread('result2.jpg')
histpred = cv2.calcHist([pred],[0,1,2],None,[8,8,8],[0,256,0,256,0,256])
histpred = cv2.normalize(histpred,histpred).flatten()

# %%
d_intersection=cv2.compareHist(histpred,historg,cv2.HISTCMP_INTERSECT)

# %%
d_chisqr = cv2.compareHist(histpred,historg,cv2.HISTCMP_CHISQR)

# %%
d_chisqr
# Out:
# 0.6075942365952451

# %%
d_intersection
# Out:
# 2.6423873556777835

# %% [markdown]
# As you can see this the CHISQR Metric for ceratotherium-simum/30.jpg
# image comes out to be 0.6075 and INTERSECTION comes out to be
# d_intersection 2.6423

# %%
tf.keras.models.load_model(
    'other_files/colorize_autoencoder.model',
    custom_objects=None,
    compile=True)
img1_color=[]
img1=img_to_array(load_img('dasypus-29-greyscale.jpg'))
img1 = resize(img1 ,(256,256))
img1_color.append(img1)
img1_color = np.array(img1_color, dtype=float)
img1_color = rgb2lab(1.0/255*img1_color)[:,:,:,0]
img1_color = img1_color.reshape(img1_color.shape+(1,))
output1 = model.predict(img1_color)
output1 = output1*128
result = np.zeros((256, 256, 3))
result[:,:,0] = img1_color[0][:,:,0]
result[:,:,1:] = output1[0]
imsave("result3.jpg", lab2rgb(result))
#/content/drive/MyDrive/Animals-151/dasypus-novemcinctus/29.jpg
# Out:
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
image_pairs = [
             
              ('result3.jpg','dasypus-29-greyscale.jpg','/content/drive/MyDrive/Animals-151/dasypus-novemcinctus/29.jpg'),
               
               ]
for c, g,o in image_pairs:
  color = mpimg.imread(c)
  gray  = mpimg.imread(g)
  true = mpimg.imread(o)
  f, axarr = plt.subplots(1, 3)
  f.set_size_inches(15, 15)
  axarr[0].imshow(gray, cmap='gray')
  axarr[1].imshow(color)
  axarr[2].imshow(true)
  axarr[0].axis('off'), axarr[1].axis('off'),axarr[2].axis('off')
  plt.show()

# %%
original = cv2.imread('/content/drive/MyDrive/Animals-151/dasypus-novemcinctus/29.jpg')
historg = cv2.calcHist([original],[0,1,2],None,[8,8,8],[0,256,0,256,0,256])
historg = cv2.normalize(historg,historg).flatten()


#dasypus-novemcinctus

# %%
pred = cv2.imread('result3.jpg')
histpred = cv2.calcHist([pred],[0,1,2],None,[8,8,8],[0,256,0,256,0,256])
histpred = cv2.normalize(histpred,histpred).flatten()

# %%
d_intersection=cv2.compareHist(histpred,historg,cv2.HISTCMP_INTERSECT)

# %%
d_chisqr = cv2.compareHist(histpred,historg,cv2.HISTCMP_CHISQR)

# %%
d_chisqr
# Out:
# 2.4043940470990104

# %%
d_intersection
# Out:
# 0.38759503183246125

# %% [markdown]
# As you can see this the CHISQR Metric for dasypus-novemcinctus/29.jpg
# image comes out to be 2.4043 and INTERSECTION comes out to be
# d_intersection 0.3875
